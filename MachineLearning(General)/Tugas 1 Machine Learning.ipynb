# %% [markdown]
# Tugas 1

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import io

# %%
from google.colab import files
data_to_load = files.upload()
# Out:
#      <input type="file" id="files-e4048c6d-b04d-40e0-acf2-815102ee34ef" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e4048c6d-b04d-40e0-acf2-815102ee34ef">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving TopDistributors.csv to TopDistributors.csv

# %%
df = pd.read_csv(io.BytesIO(data_to_load['TopDistributors.csv']))

# %%
dataset = pd.read_csv('TopDistributors.csv')
dataset
# Out:
#    RANK        DISTRIBUTORS  MOVIES      TOTAL GROSS AVERAGE GROSS  \
# 0     1         Walt Disney     588  $40,472,424,278   $68,830,654
# 1     2        Warner Bros.     824  $36,269,425,479   $44,016,293
# 2     3       Sony Pictures     747  $29,113,002,302   $38,973,229
# 3     4           Universal     535  $28,089,932,569   $52,504,547
# 4     5    20th Century Fox     525  $25,857,839,756   $49,253,028
# 5     6  Paramount Pictures     493  $24,361,425,304   $49,414,656
# 6     7           Lionsgate     426   $9,631,837,781   $22,609,948
# 7     8            New Line     209   $6,195,268,024   $29,642,431
# 8     9      Dreamworks SKG      77   $4,278,649,271   $55,566,874
# 9    10             Miramax     385   $3,836,019,208    $9,963,686
#
#   MARKET SHARE
# 0       17.02%
# 1       15.25%
# 2       12.24%
# 3       11.81%
# 4       10.88%
# 5       10.25%
# 6        4.05%
# 7        2.61%
# 8        1.80%
# 9        1.61%

# %%
dataset.describe(include='all')
# Out:
#             RANK DISTRIBUTORS      MOVIES      TOTAL GROSS AVERAGE GROSS  \
# count   10.00000           10   10.000000               10            10
# unique       NaN           10         NaN               10            10
# top          NaN  Walt Disney         NaN  $40,472,424,278   $68,830,654
# freq         NaN            1         NaN                1             1
# mean     5.50000          NaN  480.900000              NaN           NaN
# std      3.02765          NaN  224.670351              NaN           NaN
# min      1.00000          NaN   77.000000              NaN           NaN
# 25%      3.25000          NaN  395.250000              NaN           NaN
# 50%      5.50000          NaN  509.000000              NaN           NaN
# 75%      7.75000          NaN  574.750000              NaN           NaN
# max     10.00000          NaN  824.000000              NaN           NaN
#
#        MARKET SHARE
# count            10
# unique           10
# top          17.02%
# ...

# %%
dataset.corr()
# Out:
#             RANK    MOVIES
# RANK    1.000000 -0.825301
# MOVIES -0.825301  1.000000

# %%
dataset = pd.read_csv('TopDistributors.csv')
dataset.hist(column = 'MOVIES', bins=6)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f658b90ab50>]],
#       dtype=object)

# %%
dataset[["RANK","MOVIES"]].corr()
# Out:
#             RANK    MOVIES
# RANK    1.000000 -0.825301
# MOVIES -0.825301  1.000000

# %%
sns.regplot(x="RANK",y="MOVIES",data=dataset)

# %%
sns.regplot(x="RANK",y="TOTAL GROSS",data=data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-129-5d8922a8b95c> in <module>()
# ----> 1 sns.regplot(x="RANK",y="TOTAL GROSS",data=data)
#
# NameError: name 'data' is not defined

# %%
dataset.hist(column="MOVIES",by="TOTAL GROSS",bins=4)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f658718da90>,
# ...
#       dtype=object)
